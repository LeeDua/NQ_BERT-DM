# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained("twmkn9/bert-base-uncased-squad2")

model = AutoModelForQuestionAnswering.from_pretrained("twmkn9/bert-base-uncased-squad2")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-9046caa5145d> in <module>
#       1 from transformers import AutoTokenizer, AutoModelForQuestionAnswering
#       2
# ----> 3 tokenizer = AutoTokenizer.from_pretrained("twmkn9/bert-base-uncased-squad2")
#       4
#       5 model = AutoModelForQuestionAnswering.from_pretrained("twmkn9/bert-base-uncased-squad2")
#
# ~/.local/lib/python3.8/site-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     343         config = kwargs.pop("config", None)
#     344         if not isinstance(config, PretrainedConfig):
# --> 345             config = AutoConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     346
#     347         use_fast = kwargs.pop("use_fast", True)
#
# ~/.local/lib/python3.8/site-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     347             {'foo': False}
#     348         """
# --> 349         config_dict, _ = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     350
#     351         if "model_type" in config_dict:
#
# ~/.local/lib/python3.8/site-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     397         try:
#     398             # Load from URL or cache if already cached
# --> 399             resolved_config_file = cached_path(
#     400                 config_file,
#     401                 cache_dir=cache_dir,
#
# ~/.local/lib/python3.8/site-packages/transformers/file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1075     if is_remote_url(url_or_filename):
#    1076         # URL, so get it from the cache (downloading if necessary)
# -> 1077         output_path = get_from_cache(
#    1078             url_or_filename,
#    1079             cache_dir=cache_dir,
#
# ~/.local/lib/python3.8/site-packages/transformers/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, use_auth_token, local_files_only)
#    1301             logger.info("%s not found in cache or force_download set to True, downloading to %s", url, temp_file.name)
#    1302
# -> 1303             http_get(url_to_download, temp_file, proxies=proxies, resume_size=resume_size, headers=headers)
#    1304
#    1305         logger.info("storing %s in cache at %s", url, cache_path)
#
# ~/.local/lib/python3.8/site-packages/transformers/file_utils.py in http_get(url, temp_file, proxies, resume_size, headers)
#    1156     content_length = r.headers.get("Content-Length")
#    1157     total = resume_size + int(content_length) if content_length is not None else None
# -> 1158     progress = tqdm(
#    1159         unit="B",
#    1160         unit_scale=True,
#
# ~/.local/lib/python3.8/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     246         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     247         total = self.total * unit_scale if self.total else self.total
# --> 248         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     249         self.container.pbar = self
#     250         if display_here:
#
# ~/.local/lib/python3.8/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     112         # Prepare IPython progress bar
#     113         if IProgress is None:  # #187 #451 #558 #872
# --> 114             raise ImportError(
#     115                 "IProgress not found. Please update jupyter and ipywidgets."
#     116                 " See https://ipywidgets.readthedocs.io/en/stable"
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
